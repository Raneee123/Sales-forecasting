# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'F:\\New folder\\Batch67 Day27\\PRJ Sales Forecasting'

# %%
os.chdir('F:\\New folder\\Batch67 Day27\\PRJ Sales Forecasting\\')

# %%
os.getcwd()
# Out:
# 'F:\\New folder\\Batch67 Day27\\PRJ Sales Forecasting'

# %%
df=pd.read_csv('Train.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
for k in df.columns:
    print(k,len(df[k].unique()))
# Out:
# Item_Identifier 1559
# Item_Weight 416
# Item_Fat_Content 5
# Item_Visibility 7880
# Item_Type 16
# Item_MRP 5938
# Outlet_Identifier 10
# Outlet_Establishment_Year 9
# Outlet_Size 4
# Outlet_Location_Type 3
# Outlet_Type 4
# Item_Outlet_Sales 3493

# %%
len(df['Outlet_Establishment_Year'].unique())
# Out:
# 9

# %%
len(df['Outlet_Size'].unique())
# Out:
# 4

# %%
df['Outlet_Establishment_Year']
# Out:
# 0       1999
# 1       2009
# 2       1999
# 3       1998
# 4       1987
#         ...
# 8518    1987
# 8519    2002
# 8520    2004
# 8521    2009
# 8522    1997
# Name: Outlet_Establishment_Year, Length: 8523, dtype: int64

# %%
len(df['Outlet_Size'])
# Out:
# 8523

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
cat_col=[]
for k in df.dtypes.index:
    print(k)
# Out:
# Item_Identifier
# Item_Weight
# Item_Fat_Content
# Item_Visibility
# Item_Type
# Item_MRP
# Outlet_Identifier
# Outlet_Establishment_Year
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type
# Item_Outlet_Sales

# %%
cat_col=[]
for k in df.columns:
    if df.dtypes[k]=='object':
        cat_col.append(k)
print(cat_col)
# Out:
# ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
df.dtypes.index
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
print(cat_col)
# Out:
# ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
print(cat_col)
# Out:
# ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
for col in cat_col:
    print(col,len(df[col].unique()))
# Out:
# Item_Fat_Content 5
# Item_Type 16
# Outlet_Size 4
# Outlet_Location_Type 3
# Outlet_Type 4

# %%
for col in cat_col:
    print(col)
    print(df[col].value_counts())
    print( )
    print(50*'*')
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# **************************************************
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# **************************************************
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# **************************************************
# Outlet_Location_Type
# ...

# %%
miss_bool=df['Item_Weight'].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
display(df['Item_Weight'].isnull().sum())
# Out:
# 1463

# %%
Item_Weight_null =df[df['Item_Weight'].isnull()]
Item_Weight_null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
Item_Weight_null['Item_Identifier'].value_counts()
# Out:
# FDK08    2
# FDA08    2
# FDV23    2
# FDY56    2
# FDI04    2
#         ..
# FDM44    1
# FDZ48    1
# FDK41    1
# FDD57    1
# NCN18    1
# Name: Item_Identifier, Length: 1142, dtype: int64

# %%
Item_Weight_mean=df.pivot_table(values='Item_Weight',index='Item_Identifier')
Item_Weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
Item_Weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
for i, item in enumerate(df['Item_Identifier']):
    if miss_bool[i]:
        if item in Item_Weight_mean:
            df['Item_Weight'][i] = Item_Weight_mean.loc[item]['Item_Weight']
        else:
            df['Item_Weight'][i] = np.mean(df['Item_Weight'])
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_6668\373013438.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_Weight'][i] = np.mean(df['Item_Weight'])

# %%
df['Item_Weight'].head(25)
# Out:
# 0      9.300000
# 1      5.920000
# 2     17.500000
# 3     19.200000
# 4      8.930000
# 5     10.395000
# 6     13.650000
# 7     12.857645
# 8     16.200000
# 9     19.200000
# 10    11.800000
# 11    18.500000
# 12    15.100000
# 13    17.600000
# 14    16.350000
# 15     9.000000
# 16    11.800000
# 17     9.000000
# 18    12.857645
# 19    13.350000
# 20    18.850000
# 21    12.857645
# 22    14.600000
# 23    12.857645
# 24    13.850000
# Name: Item_Weight, dtype: float64

# %%
df['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
df.groupby('Outlet_Size').size()
# Out:
# Outlet_Size
# High       932
# Medium    2793
# Small     2388
# dtype: int64

# %%
display(df['Outlet_Size'].isnull().sum())
# Out:
# 2410

# %%
Outlet_Size_null=df[df['Outlet_Size'].isnull()]
Outlet_Size_null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
Outlet_Size_null['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    1855
# Grocery Store         555
# Name: Outlet_Type, dtype: int64

# %%
df.groupby(['Outlet_Type','Outlet_Size']).size()
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           528
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          1860
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# dtype: int64

# %%
outlet=df['Outlet_Type'].unique()
outlet
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
newdf=pd.DataFrame()
for i in outlet:
    df_unique=df[df['Outlet_Type']==i]
    df_unique.iloc[:,8:9]=imputer.fit_transform(df_unique.iloc[:,8:9])
    newdf=newdf.append(df_unique)
result=df.groupby(['Outlet_Type','Outlet_Size']).size()
display(result)
result=newdf.groupby(['Outlet_Type','Outlet_Size']).size()
display(result)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_6668\2746298480.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique.iloc[:,8:9]=imputer.fit_transform(df_unique.iloc[:,8:9])
# C:\Users\saura\AppData\Local\Temp\ipykernel_6668\2746298480.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newdf=newdf.append(df_unique)
# C:\Users\saura\AppData\Local\Temp\ipykernel_6668\2746298480.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df[df['Outlet_Type']=='Supermarket Type1']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
outlet
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
newdf['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
sum(newdf['Item_Visibility']==0)
# Out:
# 526

# %%
newdf['Item_Visibility'].replace([0],[newdf['Item_Visibility'].mean()],inplace=True)

# %%
newdf['Item_Visibility'].mean()
# Out:
# 0.07021339063953172

# %%
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
newdf['Item_Fat_Content']=newdf['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'})
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
newdf['New_Item_Identifier']=newdf['Item_Identifier'].str[:2]

# %%
newdf['Item_Identifier'].str[:2]
# Out:
# 0       FD
# 2       FD
# 4       NC
# 6       FD
# 8       FD
#         ..
# 8472    NC
# 8485    DR
# 8487    DR
# 8488    NC
# 8504    NC
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
newdf['Item_Identifier'].str[1:3]
# Out:
# 0       DA
# 2       DN
# 4       CD
# 6       DO
# 8       DH
#         ..
# 8472    CS
# 8485    RK
# 8487    RG
# 8488    CN
# 8504    CN
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
newdf['Item_Identifier'].str[:2]
# Out:
# 0       FD
# 2       FD
# 4       NC
# 6       FD
# 8       FD
#         ..
# 8472    NC
# 8485    DR
# 8487    DR
# 8488    NC
# 8504    NC
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000          Low Fat         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf['New_Item_Identifier'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: New_Item_Identifier, dtype: int64

# %%
newdf['New_Item_Identifier']=newdf['New_Item_Identifier'].replace({'FD':'Food','NC':'Non-Consumable','DR':'Drinks'})
newdf['New_Item_Identifier'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: New_Item_Identifier, dtype: int64

# %%
newdf.groupby(['New_Item_Identifier','Item_Fat_Content']).size()
# Out:
# New_Item_Identifier  Item_Fat_Content
# Drinks               Low Fat              728
#                      Regular               71
# Food                 Low Fat             3190
#                      Regular             2935
# Non-Consumable       Low Fat             1599
# dtype: int64

# %%
newdf.loc[newdf['New_Item_Identifier']=='Non-Consumable',['Item_Fat_Content']]='Non-Edible'

# %%
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
newdf.groupby(['New_Item_Identifier','Item_Fat_Content']).size()
# Out:
# New_Item_Identifier  Item_Fat_Content
# Drinks               Low Fat              728
#                      Regular               71
# Food                 Low Fat             3190
#                      Regular             2935
# Non-Consumable       Non-Edible          1599
# dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Item_Fat_Content',data=newdf)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
corr=newdf.corr()
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017450  0.024756
# Item_Visibility              -0.017450         1.000000 -0.005259
# Item_MRP                      0.024756        -0.005259  1.000000
# Outlet_Establishment_Year    -0.008301        -0.078355  0.005020
# Item_Outlet_Sales             0.011550        -0.134138  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.078355          -0.134138
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000       Non-Edible         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645       Non-Edible         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645       Non-Edible         0.091473
# 8504           NCN18    12.857645       Non-Edible         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf['Outlet_Years'] = 2022 - newdf['Outlet_Establishment_Year']
print (newdf['Outlet_Years'])
# Out:
# 0       23
# 2       23
# 4       35
# 6       35
# 8       20
#         ..
# 8472    37
# 8485    37
# 8487    37
# 8488    37
# 8504    37
# Name: Outlet_Years, Length: 8523, dtype: int64

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000       Non-Edible         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645       Non-Edible         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645       Non-Edible         0.091473
# 8504           NCN18    12.857645       Non-Edible         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
newdf['Outlet']=le.fit_transform(newdf['Outlet_Identifier'])
newdf['Outlet']
# Out:
# 0       9
# 2       9
# 4       1
# 6       1
# 8       7
#        ..
# 8472    5
# 8485    5
# 8487    5
# 8488    5
# 8504    5
# Name: Outlet, Length: 8523, dtype: int32

# %%
category_column=['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Identifier']
for column in category_column:
    newdf[column] = le.fit_transform(newdf[column])
display(newdf.head())
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 2           FDN15        17.50                 0         0.016760         10
# 4           NCD19         8.93                 1         0.066132          9
# 6           FDO10        13.65                 2         0.012741         13
# 8           FDH17        16.20                 2         0.016687          5
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 2  141.6180            OUT049                       1999            1
# 4   53.8614            OUT013                       1987            0
# 6   57.6588            OUT013                       1987            0
# 8   96.9726            OUT045                       2002            2
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Identifier  \
# ...

# %%
newdf = pd.get_dummies(newdf, columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Identifier'])
display (newdf.head())
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0           FDA15         9.30         0.016047          4  249.8092
# 2           FDN15        17.50         0.016760         10  141.6180
# 4           NCD19         8.93         0.066132          9   53.8614
# 6           FDO10        13.65         0.012741         13   57.6588
# 8           FDH17        16.20         0.016687          5   96.9726
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                       1999          3735.1380
# 2            OUT049                       1999          2097.2700
# 4            OUT013                       1987           994.7052
# 6            OUT013                       1987           343.5528
# 8            OUT045                       2002          1076.5986
#
#    Outlet_Years  Outlet  ...  Outlet_Location_Type_0  Outlet_Location_Type_1  \
# ...

# %%
X = newdf.drop(columns=['Outlet_Establishment_Year', 'Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales'])
X.head()
# Out:
#    Item_Weight  Item_Visibility  Item_Type  Item_MRP  Outlet_Years  Outlet  \
# 0         9.30         0.016047          4  249.8092            23       9
# 2        17.50         0.016760         10  141.6180            23       9
# 4         8.93         0.066132          9   53.8614            35       1
# 6        13.65         0.012741         13   57.6588            35       1
# 8        16.20         0.016687          5   96.9726            20       7
#
#    Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  Outlet_Size_0  \
# 0                   1                   0                   0              0
# 2                   1                   0                   0              0
# 4                   0                   1                   0              1
# 6                   0                   0                   1              1
# 8                   0                   0                   1              0
#
# ...

# %%
sns.distplot(newdf['Item_Outlet_Sales'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
newdf['Item_Outlet_Sales'] = np.log(1+newdf['Item_Outlet_Sales'])
display (newdf['Item_Outlet_Sales'])
# Out:
# 0       8.225808
# 2       7.648868
# 4       6.903451
# 6       5.842247
# 8       6.982490
#           ...
# 8472    7.411464
# 8485    8.742390
# 8487    8.321741
# 8488    7.922048
# 8504    8.328358
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
y = newdf['Item_Outlet_Sales']
y.head()
# Out:
# 0    8.225808
# 2    7.648868
# 4    6.903451
# 6    5.842247
# 8    6.982490
# Name: Item_Outlet_Sales, dtype: float64

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0              FDA15     9.300000         0.016047          4  249.8092
# 2              FDN15    17.500000         0.016760         10  141.6180
# 4              NCD19     8.930000         0.066132          9   53.8614
# 6              FDO10    13.650000         0.012741         13   57.6588
# 8              FDH17    16.200000         0.016687          5   96.9726
# ...              ...          ...              ...        ...       ...
# 8472           NCS41    12.857645         0.053185          8  182.9608
# 8485           DRK37    12.857645         0.043792         14  189.0530
# 8487           DRG13    12.857645         0.037006         14  164.7526
# 8488           NCN14    12.857645         0.091473         11  184.6608
# 8504           NCN18    12.857645         0.124111          9  111.7544
#
#      Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
print (X_train.shape, X_test.shape ,  y_train.shape, y_test.shape)
# Out:
# (5966, 22) (2557, 22) (5966,) (2557,)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
def train(model, X, y):
    # training the model
    model.fit(X, y)
    
    pred = model.predict(X)
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    print("Model Report")
    print ('Scoring - neg_mean_squared_error')
    print ( cv_score )    
    cv_score = np.abs(np.mean(cv_score))    
    print ('ABS Average of - neg_mean_squared_error',cv_score )       
    cv_score = cross_val_score(model, X, y,  cv=5)
    print ()
    print ('R2 Score ')
    print ( cv_score )    
    cv_score = np.mean(cv_score)     
    print ('Average R2 Score ',cv_score)    
    print ()
    print ('Accuracy for full Data')
    print('R2_Score:', r2_score(y,pred))
    print ()

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression(normalize=True)
train(model, X_train, y_train)
coef = pd.Series(model.coef_, X.columns).sort_values()
print (coef)
coef.plot(kind='bar', title="Model Coefficients")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# ...

# %%
model = Ridge(normalize=True)
train(model, X_train, y_train)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
model = Lasso()
train(model, X_train, y_train)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
plt.show()
# Out:
# Model Report
# Scoring - neg_mean_squared_error
# [-0.74048953 -0.75367418 -0.74780639 -0.80871532 -0.7407079 ]
# ABS Average of - neg_mean_squared_error 0.7582786656385545
#
# R2 Score
# [0.25957144 0.24467488 0.25119385 0.2685132  0.24732646]
# Average R2 Score  0.2542559654508908
#
# Accuracy for full Data
# R2_Score: 0.2549266509413125

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model,X_train, y_train)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Model Report
# Scoring - neg_mean_squared_error
# [-0.59715898 -0.57121112 -0.55090262 -0.60134248 -0.52805886]
# ABS Average of - neg_mean_squared_error 0.5697348112779176
#
# R2 Score
# [0.41572799 0.41668474 0.42376904 0.45492412 0.44306646]
# Average R2 Score  0.4308344692440652
#
# Accuracy for full Data
# R2_Score: 1.0

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X_train, y_train)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Model Report
# Scoring - neg_mean_squared_error
# [-0.30389964 -0.30617964 -0.30955416 -0.29536426 -0.30975389]
# ABS Average of - neg_mean_squared_error 0.304950318914209
#
# R2 Score
# [0.69240759 0.69219481 0.69066741 0.73491414 0.68192358]
# Average R2 Score  0.6984215058886052
#
# Accuracy for full Data
# R2_Score: 0.9583171387503574

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X_train, y_train)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Model Report
# Scoring - neg_mean_squared_error
# [-0.32824787 -0.31878182 -0.32408242 -0.31258977 -0.33137327]
# ABS Average of - neg_mean_squared_error 0.32301502882048927
#
# R2 Score
# [0.67451434 0.68017257 0.68066423 0.71501654 0.66315476]
# Average R2 Score  0.6827044863646207
#
# Accuracy for full Data
# R2_Score: 1.0

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
train(model, X_train, y_train)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Model Report
# Scoring - neg_mean_squared_error
# [-0.31148955 -0.31316432 -0.31677046 -0.30705849 -0.31289048]
# ABS Average of - neg_mean_squared_error 0.3122746598912497
#
# R2 Score
# [0.6885361  0.68614969 0.68280604 0.72226415 0.68205499]
# Average R2 Score  0.692362193672807
#
# Accuracy for full Data
# R2_Score: 0.8955802929364529
