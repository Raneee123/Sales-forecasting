# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import os

# %%
os.getcwd()
# Out:
# 'D:\\New folder\\Batch67 Day27\\PRJ Sales Forecasting'

# %%
os.chdir('D:\\New folder\Batch67 Day27\\PRJ Sales Forecasting\\')

# %%
os.getcwd()
# Out:
# 'D:\\New folder\\Batch67 Day27\\PRJ Sales Forecasting'

# %%
df=pd.read_csv('Train.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
from matplotlib.pylab import rcParams

# %%
rcParams['figure.figsize']=15,6

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# get the unique value count
for col in df.columns:
    print(col,len(df[col].unique()))
# Out:
# Item_Identifier 1559
# Item_Weight 416
# Item_Fat_Content 5
# Item_Visibility 7880
# Item_Type 16
# Item_MRP 5938
# Outlet_Identifier 10
# Outlet_Establishment_Year 9
# Outlet_Size 4
# Outlet_Location_Type 3
# Outlet_Type 4
# Item_Outlet_Sales 3493

# %%
len(df['Item_Identifier'].unique())
# Out:
# 1559

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
cat_col = []
for g in df.columns:
    if df.dtypes[g]=='object':
        cat_col.append(g)
display(cat_col)
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
df.dtypes['Item_Weight']
# Out:
# dtype('float64')

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].isna().sum()
# Out:
# 1463

# %%
cat_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
# removing Item Identifier and Outlet Identifier from the list sice they have maiximum number of distinct values where data type is object
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
display(cat_col)
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for column in cat_col:
    print(column, len(df[column].unique()))
# Out:
# Item_Fat_Content 5
# Item_Type 16
# Outlet_Size 4
# Outlet_Location_Type 3
# Outlet_Type 4

# %%
print(df['Item_Fat_Content'].unique())
print(type(df['Item_Fat_Content'].unique()))
len(df['Item_Fat_Content'].unique())
# Out:
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# <class 'numpy.ndarray'>
# 5

# %%
for column in cat_col:
    print(column)
    print(df[column].value_counts())
    print()
    print('*'*50)
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# **************************************************
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# **************************************************
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# **************************************************
# Outlet_Location_Type
# ...

# %%
#doing the null value treatment
df.isnull().sum()
# so we have two column where null value is there
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].isnull().sum()
# Out:
# 1463

# %%
miss_bool=df['Item_Weight'].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
Item_weight_null=df[df['Item_Weight'].isnull()]
Item_weight_null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
Item_weight_mean=df.pivot_table(values='Item_Weight',index='Item_Identifier')
Item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
display(df['Item_Identifier'])
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
for i, item in enumerate(df['Item_Identifier']):
    print(i,item)
# Out:
# 0 FDA15
# 1 DRC01
# 2 FDN15
# 3 FDX07
# 4 NCD19
# 5 FDP36
# 6 FDO10
# 7 FDP10
# 8 FDH17
# 9 FDU28
# 10 FDY07
# 11 FDA03
# 12 FDX32
# 13 FDS46
# 14 FDF32
# 15 FDP49
# 16 NCB42
# 17 FDP49
# 18 DRI11
# 19 FDU02
# 20 FDN22
# 21 FDW12
# 22 NCB30
# 23 FDC37
# 24 FDR28
# 25 NCD06
# 26 FDV10
# 27 DRJ59
# 28 FDE51
# 29 FDC14
# 30 FDV38
# 31 NCS17
# 32 FDP33
# 33 FDO23
# 34 DRH01
# 35 NCX29
# 36 FDV20
# 37 DRZ11
# 38 FDX10
# 39 FDB34
# 40 FDU02
# 41 FDK43
# 42 FDA46
# 43 FDC02
# 44 FDL50
# 45 FDM39
# 46 NCP05
# 47 FDV49
# 48 FDL12
# 49 FDS02
# 50 NCL17
# 51 FDM40
# 52 FDR13
# 53 FDA43
# 54 NCP18
# 55 FDK21
# 56 NCX54
# 57 DRK35
# 58 FDY21
# 59 FDI26
# 60 FDM20
# 61 FDV27
# 62 FDF09
# 63 FDY40
# 64 FDY45
# 65 FDC46
# 66 FDH19
# 67 FDZ03
# 68 DRH37
# 69 NCI17
# 70 FDJ58
# 71 FDL12
# 72 FDH35
# 73 FDG02
# 74 NCZ18
# 75 FDC29
# 76 FDQ10
# 77 FDN48
# 78 FDL04
# 79 FDV25
# 80 FDD58
# 81 FDN04
# 82 FDV45
# 83 NCL18
# 84 FDR12
# 85 FDG20
# 86 FDZ55
# 87 FDQ49
# 88 FDN33
# 89 FDN27
# 90 FDW20
# ...

# %%
for i, item in enumerate(df['Item_Identifier']):
    print(i,item)
    if miss_bool[i]:
        print(i,item)
# Out:
# 0 FDA15
# 1 DRC01
# 2 FDN15
# 3 FDX07
# 4 NCD19
# 5 FDP36
# 6 FDO10
# 7 FDP10
# 7 FDP10
# 8 FDH17
# 9 FDU28
# 10 FDY07
# 11 FDA03
# 12 FDX32
# 13 FDS46
# 14 FDF32
# 15 FDP49
# 16 NCB42
# 17 FDP49
# 18 DRI11
# 18 DRI11
# 19 FDU02
# 20 FDN22
# 21 FDW12
# 21 FDW12
# 22 NCB30
# 23 FDC37
# 23 FDC37
# 24 FDR28
# 25 NCD06
# 26 FDV10
# 27 DRJ59
# 28 FDE51
# 29 FDC14
# 29 FDC14
# 30 FDV38
# 31 NCS17
# 32 FDP33
# 33 FDO23
# 34 DRH01
# 35 NCX29
# 36 FDV20
# 36 FDV20
# 37 DRZ11
# 38 FDX10
# 38 FDX10
# 39 FDB34
# 39 FDB34
# 40 FDU02
# 41 FDK43
# 42 FDA46
# 43 FDC02
# 44 FDL50
# 45 FDM39
# 46 NCP05
# 47 FDV49
# 48 FDL12
# 49 FDS02
# 49 FDS02
# 50 NCL17
# 51 FDM40
# 52 FDR13
# 53 FDA43
# 54 NCP18
# 55 FDK21
# 56 NCX54
# 57 DRK35
# 58 FDY21
# 59 FDI26
# 59 FDI26
# 60 FDM20
# 61 FDV27
# 62 FDF09
# 62 FDF09
# 63 FDY40
# 63 FDY40
# 64 FDY45
# 64 FDY45
# 65 FDC46
# 66 FDH19
# 67 FDZ03
# 68 DRH37
# 69 NCI17
# 70 FDJ58
# 71 FDL12
# 72 FDH35
# 73 FDG02
# 74 NCZ18
# 75 FDC29
# 76 FDQ10
# 77 FDN48
# ...

# %%
print(Item_weight_mean)
print(type(Item_weight_mean))
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
Item_weight_mean.loc['DRA12']['Item_Weight']
# Out:
# 11.6

# %%
for i, item in enumerate(df['Item_Identifier']):
    if miss_bool[i]:
        if item in Item_weight_mean:
            df['Item_weight'][i]= Item_weight_mean.loc[item]['Item_Weight']
        else:
            df['Item_Weight'][i] = np.mean(df['Item_Weight'])

# %%
df['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15     9.300000          Low Fat         0.016047
# 1           DRC01     5.920000          Regular         0.019278
# 2           FDN15    17.500000          Low Fat         0.016760
# 3           FDX07    19.200000          Regular         0.000000
# 4           NCD19     8.930000          Low Fat         0.000000
# 5           FDP36    10.395000          Regular         0.000000
# 6           FDO10    13.650000          Regular         0.012741
# 7           FDP10    12.857645          Low Fat         0.127470
# 8           FDH17    16.200000          Regular         0.016687
# 9           FDU28    19.200000          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.groupby('Outlet_Size').size()
# Out:
# Outlet_Size
# High       932
# Medium    2793
# Small     2388
# dtype: int64

# %%
df.groupby('Outlet_Size').sum()
# Out:
#               Item_Weight  Item_Visibility     Item_MRP  \
# Outlet_Size
# High         12121.730000        55.879859  131809.0156
# Medium       35981.588247       167.975374  392669.3068
# Small        30686.256657       170.463790  339024.8592
#
#              Outlet_Establishment_Year  Item_Outlet_Sales
# Outlet_Size
# High                           1851884       2.142664e+06
# Medium                         5579397       7.489719e+06
# Small                          4769010       4.566212e+06

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 2410

# %%
outlet_size_null=df[df['Outlet_Size'].isnull()]
outlet_size_null
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
outlet_size_null['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    1855
# Grocery Store         555
# Name: Outlet_Type, dtype: int64

# %%
df.groupby('Outlet_Size').size()
# Out:
# Outlet_Size
# High       932
# Medium    2793
# Small     2388
# dtype: int64

# %%
df.groupby(['Outlet_Type','Outlet_Size']).size()
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           528
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          1860
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# dtype: int64

# %%
outlet=df['Outlet_Type'].unique()
outlet
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
from sklearn.impute import SimpleImputer

# %%
df[df['Outlet_Type']=='Supermarket Type1']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
df_unique=df[df['Outlet_Type']=='Supermarket Type1']
df_unique
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')
newdf=pd.DataFrame()
for i in outlet:
    df_unique=df[df['Outlet_Type']==i]
    df_unique.iloc[:,8:9]=imputer.fit_transform(df_unique.iloc[:,8:9])
    newdf=newdf.append(df_unique)
    
    
print(newdf)
result=df.groupby(['Outlet_Type','Outlet_Size']).size()
display(result)
result=newdf.groupby(['Outlet_Type','Outlet_Size']).size()
display(result)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000          Low Fat         0.000000
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
display(newdf['Outlet_Size'].isnull().sum())
# Out:
# 0

# %%
df.groupby(['Outlet_Type','Outlet_Size']).size()
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           528
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          1860
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# dtype: int64

# %%
newdf.groupby(['Outlet_Type','Outlet_Size']).size()
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small          1083
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          3715
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# dtype: int64

# %%
newdf.head(10)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15         9.30          Low Fat         0.016047
# 2            FDN15        17.50          Low Fat         0.016760
# 4            NCD19         8.93          Low Fat         0.000000
# 6            FDO10        13.65          Regular         0.012741
# 8            FDH17        16.20          Regular         0.016687
# 9            FDU28        19.20          Regular         0.094450
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 4               Household   53.8614            OUT013
# ...

# %%
sum(newdf['Item_Visibility']==0)
# Out:
# 526

# %%
newdf.loc[:,'Item_Visibility'].replace([0],[newdf['Item_Visibility'].mean()],inplace=True)

# %%
sum(newdf['Item_Visibility']==0)
# Out:
# 0

# %%
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
newdf['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'},inplace=True)

# %%
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
newdf.head(10)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15         9.30          Low Fat         0.016047
# 2            FDN15        17.50          Low Fat         0.016760
# 4            NCD19         8.93          Low Fat         0.066132
# 6            FDO10        13.65          Regular         0.012741
# 8            FDH17        16.20          Regular         0.016687
# 9            FDU28        19.20          Regular         0.094450
# 10           FDY07        11.80          Low Fat         0.066132
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 4               Household   53.8614            OUT013
# ...

# %%
print(newdf['Item_Identifier'])
print(type(newdf['Item_Identifier']))
# Out:
# 0       FDA15
# 2       FDN15
# 4       NCD19
# 6       FDO10
# 8       FDH17
#         ...
# 8472    NCS41
# 8485    DRK37
# 8487    DRG13
# 8488    NCN14
# 8504    NCN18
# Name: Item_Identifier, Length: 8523, dtype: object
# <class 'pandas.core.series.Series'>

# %%
newdf['new_item_identifier']=newdf['Item_Identifier'].str[0:2]
newdf['new_item_identifier']
# Out:
# 0       FD
# 2       FD
# 4       NC
# 6       FD
# 8       FD
#         ..
# 8472    NC
# 8485    DR
# 8487    DR
# 8488    NC
# 8504    NC
# Name: new_item_identifier, Length: 8523, dtype: object

# %%
print(type(newdf['new_item_identifier']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
newdf.head(10)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15         9.30          Low Fat         0.016047
# 2            FDN15        17.50          Low Fat         0.016760
# 4            NCD19         8.93          Low Fat         0.066132
# 6            FDO10        13.65          Regular         0.012741
# 8            FDH17        16.20          Regular         0.016687
# 9            FDU28        19.20          Regular         0.094450
# 10           FDY07        11.80          Low Fat         0.066132
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 4               Household   53.8614            OUT013
# ...

# %%
newdf['new_item_identifier'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: new_item_identifier, dtype: int64

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000          Low Fat         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf['new_item_identifier'].replace({'FD':'Food','NC':'Non Consumable','DR':'Drinks'},inplace = True)
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000          Low Fat         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf.groupby(['new_item_identifier','Item_Fat_Content']).size()
# Out:
# new_item_identifier  Item_Fat_Content
# Drinks               Low Fat              728
#                      Regular               71
# Food                 Low Fat             3190
#                      Regular             2935
# Non Consumable       Low Fat             1599
# dtype: int64

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000          Low Fat         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf['new_item_identifier'].value_counts()
# Out:
# Food              6125
# Non Consumable    1599
# Drinks             799
# Name: new_item_identifier, dtype: int64

# %%
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
newdf.groupby(['new_item_identifier','Item_Fat_Content']).size()
# Out:
# new_item_identifier  Item_Fat_Content
# Drinks               Low Fat              728
#                      Regular               71
# Food                 Low Fat             3190
#                      Regular             2935
# Non Consumable       Low Fat             1599
# dtype: int64

# %%
newdf.loc[newdf['new_item_identifier']=='Non Consumable',['Item_Fat_Content']]='Non-Edible'

# %%
newdf.loc[newdf['new_item_identifier']=='Non Consumable',['Item_Fat_Content']]
# Out:
#      Item_Fat_Content
# 4          Non-Edible
# 22         Non-Edible
# 25         Non-Edible
# 35         Non-Edible
# 46         Non-Edible
# ...               ...
# 8351       Non-Edible
# 8383       Non-Edible
# 8472       Non-Edible
# 8488       Non-Edible
# 8504       Non-Edible
#
# [1599 rows x 1 columns]

# %%
newdf['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
newdf.groupby(['new_item_identifier','Item_Fat_Content']).size()
# Out:
# new_item_identifier  Item_Fat_Content
# Drinks               Low Fat              728
#                      Regular               71
# Food                 Low Fat             3190
#                      Regular             2935
# Non Consumable       Non-Edible          1599
# dtype: int64

# %%
newdf.head(10)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15         9.30          Low Fat         0.016047
# 2            FDN15        17.50          Low Fat         0.016760
# 4            NCD19         8.93       Non-Edible         0.066132
# 6            FDO10        13.65          Regular         0.012741
# 8            FDH17        16.20          Regular         0.016687
# 9            FDU28        19.20          Regular         0.094450
# 10           FDY07        11.80          Low Fat         0.066132
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 4               Household   53.8614            OUT013
# ...

# %%
newdf['top_mentor']=2

# %%
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000       Non-Edible         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645       Non-Edible         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645       Non-Edible         0.091473
# 8504           NCN18    12.857645       Non-Edible         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf.drop(['top_mentor'],axis=1,inplace=True)
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000       Non-Edible         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645       Non-Edible         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645       Non-Edible         0.091473
# 8504           NCN18    12.857645       Non-Edible         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
newdf.head(10)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15         9.30          Low Fat         0.016047
# 2            FDN15        17.50          Low Fat         0.016760
# 4            NCD19         8.93       Non-Edible         0.066132
# 6            FDO10        13.65          Regular         0.012741
# 8            FDH17        16.20          Regular         0.016687
# 9            FDU28        19.20          Regular         0.094450
# 10           FDY07        11.80          Low Fat         0.066132
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 4               Household   53.8614            OUT013
# ...

# %%
newdf['year']=2023-newdf['Outlet_Establishment_Year']
newdf['year']
# Out:
# 0       24
# 2       24
# 4       36
# 6       36
# 8       21
#         ..
# 8472    38
# 8485    38
# 8487    38
# 8488    38
# 8504    38
# Name: year, Length: 8523, dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(newdf['Item_Weight'])
plt.show()

# %%
sns.distplot(newdf['Item_Visibility'])
plt.show()

# %%
sns.distplot(newdf['Item_MRP'])
plt.show()

# %%
sns.distplot(newdf['Item_Outlet_Sales'])
plt.show()

# %%
# The above distribution plot is right skewed, there might be outliers in the right side. to reduce tbe outliers implement log transformation
newdf['Item_Outlet_Sales']=np.log(1+newdf['Item_Outlet_Sales'])
display(newdf['Item_Outlet_Sales'])
# Out:
# 0       8.225808
# 2       7.648868
# 4       6.903451
# 6       5.842247
# 8       6.982490
#           ...
# 8472    7.411464
# 8485    8.742390
# 8487    8.321741
# 8488    7.922048
# 8504    8.328358
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
sns.distplot(newdf['Item_Outlet_Sales'])
plt.show()

# %%
sns.countplot(newdf['Item_Fat_Content'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(newdf['Item_Fat_Content'])
plt.show()

# %%
sns.countplot(newdf['Outlet_Establishment_Year'],color='Red',palette='Blues')
plt.show()

# %%
l=list(newdf['Item_Type'].unique())
chart= sns.countplot(newdf['Item_Type'])
chart.set_xticklabels(labels=l, rotation =90)
plt.show()

# %%
sns.countplot(newdf['Outlet_Type'])
plt.show()

# %%
sns.countplot(newdf['Outlet_Size'])
plt.show()

# %%
sns.countplot(newdf['Outlet_Location_Type'])
plt.show()

# %%
corr=newdf.corr()
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017450  0.024756
# Item_Visibility              -0.017450         1.000000 -0.005259
# Item_MRP                      0.024756        -0.005259  1.000000
# Outlet_Establishment_Year    -0.008301        -0.078355  0.005020
# Item_Outlet_Sales             0.008059        -0.202466  0.509886
# year                          0.008301         0.078355 -0.005020
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.008301           0.008059
# Item_Visibility                            -0.078355          -0.202466
# Item_MRP                                    0.005020           0.509886
# Outlet_Establishment_Year                   1.000000           0.077032
# Item_Outlet_Sales                           0.077032           1.000000
# ...

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
newdf['outlet']=le.fit_transform(newdf['Outlet_Identifier'])
newdf
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 2              FDN15    17.500000          Low Fat         0.016760
# 4              NCD19     8.930000       Non-Edible         0.066132
# 6              FDO10    13.650000          Regular         0.012741
# 8              FDH17    16.200000          Regular         0.016687
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645       Non-Edible         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645       Non-Edible         0.091473
# 8504           NCN18    12.857645       Non-Edible         0.124111
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
cat_col=['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type','new_item_identifier']
for k in cat_col:
    newdf[k]=le.fit_transform(newdf[k])
newdf
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000                 0         0.016047
# 2              FDN15    17.500000                 0         0.016760
# 4              NCD19     8.930000                 1         0.066132
# 6              FDO10    13.650000                 2         0.012741
# 8              FDH17    16.200000                 2         0.016687
# ...              ...          ...               ...              ...
# 8472           NCS41    12.857645                 1         0.053185
# 8485           DRK37    12.857645                 0         0.043792
# 8487           DRG13    12.857645                 0         0.037006
# 8488           NCN14    12.857645                 1         0.091473
# 8504           NCN18    12.857645                 1         0.124111
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
newdf=pd.get_dummies(newdf,columns=['Item_Fat_Content','Outlet_Size','Outlet_Location_Type','Outlet_Type','new_item_identifier'])
newdf
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0              FDA15     9.300000         0.016047          4  249.8092
# 2              FDN15    17.500000         0.016760         10  141.6180
# 4              NCD19     8.930000         0.066132          9   53.8614
# 6              FDO10    13.650000         0.012741         13   57.6588
# 8              FDH17    16.200000         0.016687          5   96.9726
# ...              ...          ...              ...        ...       ...
# 8472           NCS41    12.857645         0.053185          8  182.9608
# 8485           DRK37    12.857645         0.043792         14  189.0530
# 8487           DRG13    12.857645         0.037006         14  164.7526
# 8488           NCN14    12.857645         0.091473         11  184.6608
# 8504           NCN18    12.857645         0.124111          9  111.7544
#
#      Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  year  \
# ...

# %%
x=newdf.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Item_Outlet_Sales'], axis=1)
x
# Out:
#       Item_Weight  Item_Visibility  Item_Type  Item_MRP  year  outlet  \
# 0        9.300000         0.016047          4  249.8092    24       9
# 2       17.500000         0.016760         10  141.6180    24       9
# 4        8.930000         0.066132          9   53.8614    36       1
# 6       13.650000         0.012741         13   57.6588    36       1
# 8       16.200000         0.016687          5   96.9726    21       7
# ...           ...              ...        ...       ...   ...     ...
# 8472    12.857645         0.053185          8  182.9608    38       5
# 8485    12.857645         0.043792         14  189.0530    38       5
# 8487    12.857645         0.037006         14  164.7526    38       5
# 8488    12.857645         0.091473         11  184.6608    38       5
# 8504    12.857645         0.124111          9  111.7544    38       5
#
#       Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  \
# ...

# %%
y=newdf['Item_Outlet_Sales']
y
# Out:
# 0       8.225808
# 2       7.648868
# 4       6.903451
# 6       5.842247
# 8       6.982490
#           ...
# 8472    7.411464
# 8485    8.742390
# 8487    8.321741
# 8488    7.922048
# 8504    8.328358
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6818, 22)
# (1705, 22)
# (6818,)
# (1705,)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
def train(model,x,y):
    #training the model
    model.fit(x,y)
    predict=model.predict(x)
    # perform cross-validation
    cv_score= cross_val_score(model,x,y,scoring='neg_mean_squared_error',cv=5)
    print('Model Report')
    print('scoring- neg_mean_squared_error')
    print(cv_score)
    cv_score=np.abs(np.mean(cv_score))
    print('ABS Average of -neg_mean_squared_error', cv_score)
    cv_score=cross_val_score(model,x,y,cv=5)
    print()
    print('R2 score')
    print(cv_score)
    cv_score=np.mean(cv_score)
    print('Average R2 score', cv_score)
    print()
    print('Accuracy for full data')
    print('R2_score', r2_score(y,predict))
    print()

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
model=LinearRegression(normalize=True)
train(model,x_train,y_train)
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.27828584 -0.29665817 -0.27538598 -0.2934152  -0.28624834]
# ABS Average of -neg_mean_squared_error 0.28599870650252796
#
# R2 score
# [0.72962971 0.70920867 0.72144615 0.73164715 0.70712107]
# Average R2 score 0.7198105519034561
#
# Accuracy for full data
# R2_score 0.7220867527575706

# %%
coeff=pd.Series(model.coef_,x.columns).sort_values()
coeff.plot(kind='bar',title='Model Coefficient')
plt.show()

# %%
model=Ridge(normalize=True)
train(model,x_train,y_train)
coeff=pd.Series(model.coef_,x.columns).sort_values()
coeff.plot(kind='bar',title='Model Coefficient')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.42737971 -0.42891434 -0.40721026 -0.46328366 -0.40851688]
# ABS Average of -neg_mean_squared_error 0.42706097020108336
#
# R2 score
# [0.58477667 0.57956807 0.58810544 0.57628817 0.58202033]
# Average R2 score 0.5821517356862753
#
# Accuracy for full data
# R2_score 0.5835762741444361

# %%
model=Lasso()
train(model,x_train,y_train)
coeff=pd.Series(model.coef_,x.columns).sort_values()
coeff.plot(kind='bar',title='Model Coefficient')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.74289285 -0.77623912 -0.72766457 -0.80496198 -0.72860551]
# ABS Average of -neg_mean_squared_error 0.7560728044792313
#
# R2 score
# [0.27823797 0.23911215 0.26396481 0.26379465 0.25451725]
# Average R2 score 0.259925366474859
#
# Accuracy for full data
# R2_score 0.2609085036501595

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
train(model,x_train,y_train)
coeff=pd.Series(model.feature_importances_,x.columns).sort_values(ascending=False)
coeff.plot(kind='bar',title='Feature Importances')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.56152461 -0.57299374 -0.56875073 -0.60259793 -0.5624398 ]
# ABS Average of -neg_mean_squared_error 0.5736613613108015
#
# R2 score
# [0.46859594 0.41923748 0.42440235 0.45051439 0.4253709 ]
# Average R2 score 0.43762421143039576
#
# Accuracy for full data
# R2_score 1.0

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
train(model,x_train,y_train)
coeff=pd.Series(model.feature_importances_,x.columns).sort_values(ascending=False)
coeff.plot(kind='bar',title= 'Feature Importances')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.29702836 -0.32866979 -0.28974929 -0.30362156 -0.31319291]
# ABS Average of -neg_mean_squared_error 0.30645238382739737
#
# R2 score
# [0.71288339 0.67960537 0.70588238 0.72211871 0.68129819]
# Average R2 score 0.7003576073584058
#
# Accuracy for full data
# R2_score 0.9589497697881109

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
train(model,x_train,y_train)
coeff=pd.Series(model.feature_importances_,x.columns).sort_values(ascending=False)
coeff.plot(kind='bar',title='Feature Importances')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.32152107 -0.34794529 -0.30816707 -0.32652294 -0.33605139]
# ABS Average of -neg_mean_squared_error 0.3280415509698651
#
# R2 score
# [0.68622546 0.65658651 0.68921407 0.70056516 0.65549475]
# Average R2 score 0.6776171906874631
#
# Accuracy for full data
# R2_score 1.0

# %%
from lightgbm import LGBMRegressor
model=LGBMRegressor()
train(model,x_train,y_train)
coeff=pd.Series(model.feature_importances_,x.columns).sort_values(ascending=False)
coeff.plot(kind='bar',title='Model Coefficient')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.2694176  -0.29790871 -0.27065293 -0.27931248 -0.28087737]
# ABS Average of -neg_mean_squared_error 0.27963381690552447
#
# R2 score
# [0.73824571 0.70798287 0.72623364 0.74454527 0.71261646]
# Average R2 score 0.725924790118537
#
# Accuracy for full data
# R2_score 0.8065516821649348

# %%
from xgboost import XGBRegressor
model=XGBRegressor()
train(model,x_train,y_train)
coeff=pd.Series(model.feature_importances_,x.columns).sort_values(ascending=False)
coeff.plot(kind='bar',title='Feature Importances')
plt.show()
# Out:
# Model Report
# scoring- neg_mean_squared_error
# [-0.3096438  -0.3332503  -0.30701613 -0.31350602 -0.30716948]
# ABS Average of -neg_mean_squared_error 0.3141171454799053
#
# R2 score
# [0.69916369 0.67334021 0.68945214 0.71327241 0.68571532]
# Average R2 score 0.6921887565132369
#
# Accuracy for full data
# R2_score 0.8883763385285333

# %%
from sklearn.model_selection import RandomizedSearchCV
max_features=['auto','sqrt']
max_depth=[int(x) for x in np.linspace(5,30, num=6)]
min_samples_split=[2,5,10,15,100]
min_samples_leaf=[1,2,5,10]

# %%
random_grid = {
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf=RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)
display (rf.fit(x_train, y_train))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=100; total time=   0.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   1.9s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   1.9s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   1.9s
# ...

# %%
print(rf.best_params_)
print(rf.best_score_)
predictions=rf.predict(x_test)
display(r2_score(y_test,predictions))
display(predictions)
# Out:
# {'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 5}
# -0.2686551994999645
# 0.7213651147064872
# array([6.87054157, 6.59899739, 5.21913392, ..., 7.56111134, 7.26443317,
#        6.98361811])

# %%
sns.distplot(y_test-predictions)
plt.show()

# %%
from scipy.stats import uniform, randint

# %%
params={
    'gamma': uniform(0,0.5),
    'learning_rate': uniform(0.03,0.3),
    'max_depth': randint(2,6),
    'n_estimators': randint(100,150),
    'sub_sample': uniform(0.6,0.4)
    
}

# %%
lgb=LGBMRegressor()
lgb=RandomizedSearchCV(estimator=lgb,param_distributions=params,scoring='neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=-1)
lgb.fit(x,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [LightGBM] [Warning] Unknown parameter: gamma
# [LightGBM] [Warning] Unknown parameter: sub_sample
# RandomizedSearchCV(cv=5, estimator=LGBMRegressor(), n_jobs=-1,
#                    param_distributions={'gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000027806C98F70>,
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000278073810A0>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002780811B9A0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000278039BE160>,
#                                         'sub_sample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002781693B040>},
# ...

# %%
print(lgb.best_params_)
# Out:
# {'gamma': 0.4692763545078751, 'learning_rate': 0.030233629752304297, 'max_depth': 5, 'n_estimators': 120, 'sub_sample': 0.8469926038510867}

# %%
print(lgb.best_score_)
# Out:
# -0.31955170401548866

# %%
predictions=lgb.predict(x_test)
display(r2_score(y_test,predictions))
display(predictions)
# Out:
# 0.7470836606509542
# array([6.78527193, 6.62776816, 5.14837947, ..., 7.57252331, 7.3206739 ,
#        6.95777586])

# %%
sns.distplot(y_test-predictions)
plt.show()

# %%
params={
    'gamma': uniform(0,0.5),
    'learning_rate': uniform(0.03,0.3),
    'max_depth': randint(2,6),
    'n_estimators': randint(100,150),
    'sub_sample': uniform(0.6,0.4)
    
}

# %%
model=XGBRegressor()

# %%
model=RandomizedSearchCV(estimator=model,param_distributions=params,scoring='neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=-1)
model.fit(x,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [12:43:55] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "sub_sample" } are not used.
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
# ...

# %%
model.best_params_
# Out:
# {'gamma': 0.19993048585762774,
#  'learning_rate': 0.04399969896408463,
#  'max_depth': 5,
#  'n_estimators': 115,
#  'sub_sample': 0.6931085361721216}

# %%
model.best_score_
# Out:
# -0.33010496777808235

# %%
predictions=model.predict(x_test)
display(r2_score(y_test,predictions))
display(predictions)
# Out:
# 0.752872789866658
# array([6.678703 , 6.632305 , 5.1882873, ..., 7.5572033, 7.324455 ,
#        6.8764496], dtype=float32)

# %%
sns.distplot(y_test-predictions)
plt.show()
